# %%
from principal_RBM_alpha import *

# %%
X = lire_alpha_digit(['Z'])
p = len(X[0])
q = 100
Rbm = init_RBM(p,q)
Rbm,error = train_RBM(Rbm,X,learning_rate=0.1, epochs=400, batch_size=3)
plt.plot(error)
# Out:
# Epoch :  0 Erreur :  0.17797019471727865
# Epoch :  10 Erreur :  0.08602099115774085
# Epoch :  20 Erreur :  0.05325019230898137
# Epoch :  30 Erreur :  0.03623555079439696
# Epoch :  40 Erreur :  0.02661036850471858
# Epoch :  50 Erreur :  0.019797201996107634
# Epoch :  60 Erreur :  0.014884552247341686
# Epoch :  70 Erreur :  0.011031854850869443
# Epoch :  80 Erreur :  0.008808068537042352
# Epoch :  90 Erreur :  0.006998132210347742
# Epoch :  100 Erreur :  0.005743091150597469
# Epoch :  110 Erreur :  0.004874804539198694
# Epoch :  120 Erreur :  0.004215952368020155
# Epoch :  130 Erreur :  0.0035206406672608896
# Epoch :  140 Erreur :  0.0031369316537450003
# Epoch :  150 Erreur :  0.0027362908567759347
# Epoch :  160 Erreur :  0.0024441240315223665
# Epoch :  170 Erreur :  0.0023246224690947463
# Epoch :  180 Erreur :  0.001855870462508498
# Epoch :  190 Erreur :  0.0017506707665828761
# Epoch :  200 Erreur :  0.0015431022492033875
# ...

# %%
generer_image_RBM(Rbm, 500, 3)

# %%
from principal_DBN_alpha import *

# %%
config = [len(X[0]),100,50,100]
X  = lire_alpha_digit(['X'])
Dbm = init_DBN(config)
Dbm = train_DBN(Dbm, X, 0.1, 100, 3)
# Out:
# Epoch :  0 Erreur :  0.18547092958936037
# Epoch :  10 Erreur :  0.08251579692162589
# Epoch :  20 Erreur :  0.045164458132072316
# Epoch :  30 Erreur :  0.026802763012848528
# Epoch :  40 Erreur :  0.016433869674197292
# Epoch :  50 Erreur :  0.011437701528389719
# Epoch :  60 Erreur :  0.00794666894982108
# Epoch :  70 Erreur :  0.006329925276880427
# Epoch :  80 Erreur :  0.0047362885646480375
# Epoch :  90 Erreur :  0.0037258127630872186
# Epoch :  0 Erreur :  0.1870649285199345
# Epoch :  10 Erreur :  0.11555935282633882
# Epoch :  20 Erreur :  0.05618043829262726
# Epoch :  30 Erreur :  0.03513125445574017
# Epoch :  40 Erreur :  0.022163078788454485
# Epoch :  50 Erreur :  0.015921422446728808
# Epoch :  60 Erreur :  0.011646539013820238
# Epoch :  70 Erreur :  0.008950096932736944
# Epoch :  80 Erreur :  0.006550541374205934
# Epoch :  90 Erreur :  0.005519618310385705
# Epoch :  0 Erreur :  0.2718986610279264
# Epoch :  10 Erreur :  0.1634494020773696
# ...

# %%
generer_image_DBN(Dbm,config, 500, 2)
