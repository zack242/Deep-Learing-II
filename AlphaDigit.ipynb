# %%
from principal_RBM_MNIST import *

# %%
X = lire_alpha_digit(['Z'])
p = len(X[0])
q = 100
Rbm = init_RBM(p,q)
rbm = train_RBM(Rbm,X,learning_rate=0.1,epochs=100,batch_size=10)

# %%
print(Rbm)

# %%
generer_image_RBM(rbm, 500, 3)

# %%
X = lire_alpha_digit(['A','B','Z','0'])
p = len(X[0])
q = 100
Rbm = init_RBM(p,q)
Rbm = train_RBM(Rbm,X,learning_rate=0.1, epochs=400, batch_size=10)

# %%
generer_image_RBM(Rbm, 500, 40)

# %%
from principal_DBN_alpha import *

# %%
#congif = ['taille de la couche d'entrée', 'taille de la couche cachée 1', 'taille de la couche cachée 2', ...]
config = [len(X[0]),100,50,100]
X  = lire_alpha_digit(['A','B','9'])
# Create a new DBM object
dbm = init_DBN(config)

# %%
Dbm = train_DBN(dbm, X, 0.1, 400, 10)
# Out:
# Epoch :  0 Erreur :  0.2203322713701768
# Epoch :  10 Erreur :  0.13624639960328266
# Epoch :  20 Erreur :  0.1061017288871747
# Epoch :  30 Erreur :  0.0853892017307873
# Epoch :  40 Erreur :  0.07145969172005948
# Epoch :  50 Erreur :  0.05980169192127955
# Epoch :  60 Erreur :  0.05117445052151202
# Epoch :  70 Erreur :  0.04368760183848722
# Epoch :  80 Erreur :  0.038223527053235784
# Epoch :  90 Erreur :  0.034260773783825804
# Epoch :  100 Erreur :  0.03015982656518111
# Epoch :  110 Erreur :  0.02721445346183113
# Epoch :  120 Erreur :  0.024756971536369878
# Epoch :  130 Erreur :  0.022772631975885697
# Epoch :  140 Erreur :  0.020810018742749306
# Epoch :  150 Erreur :  0.019109914629535693
# Epoch :  160 Erreur :  0.017431129172867554
# Epoch :  170 Erreur :  0.016229415968832598
# Epoch :  180 Erreur :  0.01502472767637858
# Epoch :  190 Erreur :  0.014029713321695085
# Epoch :  200 Erreur :  0.013039781129334448
# Epoch :  210 Erreur :  0.012172096044567338
# ...

# %%
generer_image_DBN(Dbm,config, 500, 10)
